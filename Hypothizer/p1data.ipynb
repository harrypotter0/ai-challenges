# %%
import pickle
df = pickle.load( open( "df_train_api.pk", "rb" ) )
df
# df.info()
# Out:
#                                                  groups  \
# 270                                 ACME VISUAL SYSTEMS
# 271                                         TAX INVOICE
# 272                                 ACME VISUAL SYSTEMS
# 273          808, JANTA FLAT, GTB ENCLAVE, NANAD NAGARI
# 274                                        DELHI-110093
# 275                                 CONTACT:-9871101347
# 276                   EMAIL:-acmevisualsystems@mail.com
# 277                                         Invoice No.
# 278                                              GS-032
# 279                                     Delivery Note:-
# 280                                               Dated
# 281                                          22/08/2017
# 282                               Mode/Terms of Payment
# 283                               100% against Delivery
# 284                                  Other Reference(s)
# 285                                     Supplier ref.:-
# ...

# %%
df = df.groupby('label').nunique()

print (df)
# Out:
#        groups  type  data  label  coords
# label
# 0        3118  2852    75      1    4091
# 1          61    45    69      1      63
# 2          66    63    70      1      66
# 8          16    17    22      1      18
# 14         24    24    25      1      27
# 18         69    40    71      1      69

# %%
df = df.groupby('').nunique()

print (df)
